# %%
# !pip install tiktoken
# Out:
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.12/dist-packages (0.12.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken) (2025.11.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from tiktoken) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken) (2026.1.4)

# %%
import importlib
import tiktoken

# %%
tokenizer = tiktoken.get_encoding("gpt2")

# %%
text = (
    "Artificial intelligence is transforming the world. "
    "It enables machines to learn from data and make decisions. "
    "Deep learning models use neural networks with many layers."
)

# %% [markdown]
# ### text to tokens

# %%
integers = tokenizer.encode(text, allowed_special={"<|endoftext|>"})
print(integers)
# Out:
# [8001, 9542, 4430, 318, 25449, 262, 995, 13, 632, 13536, 8217, 284, 2193, 422, 1366, 290, 787, 5370, 13, 10766, 4673, 4981, 779, 17019, 7686, 351, 867, 11685, 13]

# %% [markdown]
# ### tokens back to words

# %%
strings = tokenizer.decode(integers)
print(strings)
# Out:
# Artificial intelligence is transforming the world. It enables machines to learn from data and make decisions. Deep learning models use neural networks with many layers.

# %%
integers = tokenizer.encode("Akwirw ier")
print(integers)
# Out:
# [33901, 86, 343, 86, 220, 959]

# %%
strings = tokenizer.decode(integers)
print(strings)
# Out:
# Akwirw ier
